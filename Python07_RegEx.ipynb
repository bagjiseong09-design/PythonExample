# %%
import re
txt = "The rain in Spain"
x = re.findall("Portugal", txt)
print(x)
[]
# Out:
# []
# []

# %%
import re
txt = "The rain in Spain"
x = re.findall("ai", txt)
print(x)
['ai', 'ai']
# Out:
# ['ai', 'ai']
# ['ai', 'ai']

# %%
import re
txt = "The rain in Spain"
x = re.search("^The.*Spain$", txt)
print(x)
# Out:
# <re.Match object; span=(0, 17), match='The rain in Spain'>

# %%
import re
txt = "The rain in Spain"
x = re.search("\s", txt)
print("The first white-space character is located in position:", x.start())
# Out:
# The first white-space character is located in position: 3
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\jisoe\AppData\Local\Temp\ipykernel_25068\4009967224.py:3: SyntaxWarning: invalid escape sequence '\s'
#   x = re.search("\s", txt)

# %%
import re
txt = "The rain in Spain"
x = re.search("Portugal", txt)
print(x)
# Out:
# None

# %%
import re
txt = "The rain in Spain"
x = re.split("\s", txt)
print(x)
# Out:
# ['The', 'rain', 'in', 'Spain']
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\jisoe\AppData\Local\Temp\ipykernel_25068\4124838735.py:3: SyntaxWarning: invalid escape sequence '\s'
#   x = re.split("\s", txt)

# %%
import re
txt = "The rain in Spain"
x = re.split("\s", txt, 1)
print(x)
# Out:
# ['The', 'rain in Spain']
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\jisoe\AppData\Local\Temp\ipykernel_25068\3056546710.py:3: SyntaxWarning: invalid escape sequence '\s'
#   x = re.split("\s", txt, 1)
# C:\Users\jisoe\AppData\Local\Temp\ipykernel_25068\3056546710.py:3: DeprecationWarning: 'maxsplit' is passed as positional argument
#   x = re.split("\s", txt, 1)

# %%
import re
txt = "The rain in Spain"
x = re.sub("\s", "9", txt)
print(x)
# Out:
# The9rain9in9Spain
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\jisoe\AppData\Local\Temp\ipykernel_25068\21386051.py:3: SyntaxWarning: invalid escape sequence '\s'
#   x = re.sub("\s", "9", txt)

# %%
import re
txt = "The rain in Spain"
x = re.sub("\s", "9", txt, 2)
print(x)
# Out:
# The9rain9in Spain
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\jisoe\AppData\Local\Temp\ipykernel_25068\3838997704.py:3: SyntaxWarning: invalid escape sequence '\s'
#   x = re.sub("\s", "9", txt, 2)
# C:\Users\jisoe\AppData\Local\Temp\ipykernel_25068\3838997704.py:3: DeprecationWarning: 'count' is passed as positional argument
#   x = re.sub("\s", "9", txt, 2)

# %%
import re
txt = "The rain in Spain"
x = re.search("ai", txt)
print(x)
# Out:
# <re.Match object; span=(5, 7), match='ai'>

# %%
try:
 print(x)
except NameError:
 print("Variable x is not defined")
except:
 print("Something else went wrong")
# Out:
# <re.Match object; span=(5, 7), match='ai'>

# %%
price = 59
txt = f"The price is {price} dollars"
print(txt)
# Out:
# The price is 59 dollars

# %%
txt = f"The price is {95:.2f} dollars"
print(txt)
# Out:
# The price is 95.00 dollars

# %%
def myconverter(x):
 return x * 0.3048
txt = f"The plane is flying at a {myconverter(30000)} meter altitude"
print(txt)
# Out:
# The plane is flying at a 9144.0 meter altitude
